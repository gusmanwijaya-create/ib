# %% [markdown]
# <a href="https://colab.research.google.com/github/gusmanwijaya-create/ib/blob/main/gatau%20tugas%20apa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# definisikan List kosong untuk menyimpan angka
List = []

# %%
#input 10 angka
for i in range(10):
  angka = int(input("masukan angka :"))
  list.append(angka)
# Out:
# masukan angka :30
# masukan angka :46
# masukan angka :67
# masukan angka :89
# masukan angka :0
# masukan angka :100
# masukan angka :88
# masukan angka :72
# masukan angka :56
# masukan angka :78

# %%
# tampilkan nilai maksimum, minimum, dan rata-rata
print("List angka:", list)
print("Nilai maksimum:", max(list))
print("Nilai minimum:", min(list))
print("Rata-rata:", sum(list)/len(list))
# Out:
# List angka: [30, 46, 67, 89, 0, 100, 88, 72, 56, 78]
# Nilai maksimum: 100
# Nilai minimum: 0
# Rata-rata: 62.6

# %%
import matplotlib.pyplot as plt
plt.bar(range(len(list)), list)
plt.title("Grafik Array")
plt.xlabel("Indeks")
plt.ylabel("Nilai")
plt.show()

# %%
#Inisialisasi penghitung
jumlah_lulus = 0
jumlah_tidak_lulus = 0

for nilai in list:
    if nilai >= 60:
        jumlah_lulus += 1
    else:
        jumlah_tidak_lulus += 1

print(f"Jumlah siswa yang lulus: {jumlah_lulus}")
print(f"Jumlah siswa yang tidak lulus: {jumlah_tidak_lulus}")
# Out:
# Jumlah siswa yang lulus: 6
# Jumlah siswa yang tidak lulus: 4

# %%
kategori = ['Lulus', 'Tidak Lulus']
jumlah = [jumlah_lulus, jumlah_tidak_lulus]

plt.figure(figsize=(8, 5))
plt.bar(kategori, jumlah, color=['#4CAF50', '#F44336']) # Hijau untuk lulus, Merah untuk tidak

plt.title('Statistik Kelulusan Mahasiswa')
plt.xlabel('Status')
plt.ylabel('Jumlah Mahasiswa')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
