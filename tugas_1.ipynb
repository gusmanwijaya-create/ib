# %% [markdown]
# <a href="https://colab.research.google.com/github/gusmanwijaya-create/ib/blob/main/tugas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Buat list berisi nama 5 mahasiswa
mahasiswa = ["Andi", "Budi", "Citra", "Dewi", "Eko"]
print("List nama mahasiswa:")
print(mahasiswa)
# Out:
# List nama mahasiswa:
# ['Andi', 'Budi', 'Citra', 'Dewi', 'Eko']

# %%
mahasiswa.append("budi")
print("setelah ditambahkan nama baru")
print(mahasiswa)
# Out:
# setalah ditambahkan nama baru
# ['Andi', 'Budi', 'Citra', 'Dewi', 'Eko', 'budi']

# %%
mahasiswa.remove("Eko")
print("setelah menghapus nama Eko")
print(mahasiswa)
# Out:
# setelah menghapus nama Eko
# ['Andi', 'Budi', 'Citra', 'Dewi', 'budi']
