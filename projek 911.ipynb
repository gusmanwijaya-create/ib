# %% [markdown]
# <a href="https://colab.research.google.com/github/gusmanwijaya-create/ib/blob/main/projek%20911.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# definisikan list kosong untuk tempat menyimpan angka
list = []

# %%
#input 10 angka
for i in range(10):
  angka = int (input("masukan angka :"))
  list.append(angka)
# Out:
# masukan angka :60
# masukan angka :77
# masukan angka :89
# masukan angka :90
# masukan angka :97
# masukan angka :86
# masukan angka :76
# masukan angka :56
# masukan angka :46
# masukan angka :100

# %%
print("List:", list)
print("Nilai maksimum:", max(list))
print("Nilai minimum:", min(list))
print("Rata-rata:", sum(list)/len(list))
# Out:
# List: [50, 60, 87, 67, 97, 80, 77, 98, 100, 57, 88, 72, 56, 44, 50, 70, 80, 42, 100, 36, 88, 97, 67, 90, 60, 77, 89, 90, 97, 86, 76, 56, 46, 100]
# Nilai maksimum: 100
# Nilai minimum: 36
# Rata-rata: 74.41176470588235

# %%
#Inisialisasi penghitung
jumlah_lulus = 0
jumlah_tidak_lulus = 0

for nilai in list:
    if nilai >= 60:
        jumlah_lulus += 1
    else:
        jumlah_tidak_lulus += 1

print(f"Jumlah siswa yang lulus: {jumlah_lulus}")
print(f"Jumlah siswa yang tidak lulus: {jumlah_tidak_lulus}")
# Out:
# Jumlah siswa yang lulus: 25
# Jumlah siswa yang tidak lulus: 9

# %%
import matplotlib.pyplot as plt
plt.bar(range(len(list)), list)
plt.title("Grafik Array")
plt.xlabel("Indeks")
plt.ylabel("Nilai")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.bar(kategori, jumlah, color=['#4CAF50', '#F44336']) # Hijau untuk lulus, Merah untuk tidak

plt.title('Statistik Kelulusan Mahasiswa')
plt.xlabel('Status')
plt.ylabel('Jumlah Mahasiswa')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
